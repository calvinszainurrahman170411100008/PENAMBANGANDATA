# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("varian Tenaga Kerja Indonesia   :",df['TKI'].count())
print("varian Nelayan Ikan             :",df['NELAYAN'].count())
print("varian Pengangguran             :",df['PNG'].count())
print("varian Pegawai Negeri Sipil     :",df['PNS'].count())
# Out:
# varian Tenaga Kerja Indonesia   : 500
# varian Nelayan Ikan             : 500
# varian Pengangguran             : 500
# varian Pegawai Negeri Sipil     : 500

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("rata-rata Tenaga Kerja Indonesia   :",df['TKI'].mean())
print("rata-rata Nelayan Ikan             :",df['NELAYAN'].mean())
print("rata-rata Pengangguran             :",df['PNG'].mean())
print("rata-rata Pegawai Negeri Sipil     :",df['PNS'].mean())
# Out:
# rata-rata Tenaga Kerja Indonesia   : 296.372
# rata-rata Nelayan Ikan             : 82.856
# rata-rata Pengangguran             : 86.566
# rata-rata Pegawai Negeri Sipil     : 112.996

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
makan=("Q2 Tenaga Kerja Indonesia",df['TKI'].median())
print (makan)
# Out:
# ('Q2 Tenaga Kerja Indonesia', 205.5)

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("modus Tenaga Kerja Indonesia   :",df['TKI'].mode())
print("modus Nelayan Ikan             :",df['NELAYAN'].mode())
print("modus Pengangguran             :",df['PNG'].mode())
print("modus Pegawai Negeri Sipil     :",df['PNS'].mode())
# Out:
# modus Tenaga Kerja Indonesia   : 0    198
# dtype: int64
# modus Nelayan Ikan             : 0    25
# dtype: int64
# modus Pengangguran             : 0    25
# dtype: int64
# modus Pegawai Negeri Sipil     : 0    20
# dtype: int64

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("standar deviasi Tenaga Kerja Indonesia   :",df['TKI'].std())
print("standar deviasi Nelayan Ikan             :",df['NELAYAN'].std())
print("standar deviasi Pengangguran             :",df['PNG'].std())
print("standar deviasi Pegawai Negeri Sipil     :",df['PNS'].std())
# Out:
# standar deviasi Tenaga Kerja Indonesia   : 257.461676071004
# standar deviasi Nelayan Ikan             : 194.34524798623139
# standar deviasi Pengangguran             : 197.48695105163623
# standar deviasi Pegawai Negeri Sipil     : 260.19936087315347

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("skewnes Tenaga Kerja Indonesia   :",df['TKI'].skew())
print("skewnes  Nelayan Ikan             :",df['NELAYAN'].skew())
print("skewnes  Pengangguran             :",df['PNG'].skew())
print("skewnes  Pegawai Negeri Sipil     :",df['PNS'].skew())
# Out:
# skewnes Tenaga Kerja Indonesia   : 3.6100153733248157
# skewnes  Nelayan Ikan             : 6.275034666861863
# skewnes  Pengangguran             : 6.0268693397247235
# skewnes  Pegawai Negeri Sipil     : 4.765218397488693

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("min Tenaga Kerja Indonesia   :",df['TKI'].min())
print("min Nelayan Ikan             :",df['NELAYAN'].min())
print("min Pengangguran             :",df['PNG'].min())
print("min Pegawai Negeri Sipil     :",df['PNS'].min())
# Out:
# min Tenaga Kerja Indonesia   : 63
# min Nelayan Ikan             : 10
# min Pengangguran             : 10
# min Pegawai Negeri Sipil     : 6

# %%
import pandas as dt
df=dt.read_csv("calvins.csv")
df['TKI'].describe()
df['NELAYAN'].describe()
df['PNG'].describe()
df['PNS'].describe()
print("max Tenaga Kerja Indonesia   :",df['TKI'].max())
print("max Nelayan Ikan             :",df['NELAYAN'].max())
print("max Pengangguran             :",df['PNG'].max())
print("max Pegawai Negeri Sipil     :",df['PNS'].max())
# Out:
# max Tenaga Kerja Indonesia   : 2110
# max Nelayan Ikan             : 2000
# max Pengangguran             : 2000
# max Pegawai Negeri Sipil     : 2000

# %%
import numpy as ip
import matplotlib.pyplot as mat
from scipy import stats
import pandas as data

data.read_csv("calvins.csv")
# Out:
#      TKI  NELAYAN   PNG  PNS
# 0    187       16    27   22
# 1    699       64    19   53
# 2    490       60    16   91
# 3    182       14    14  168
# 4    195       27    22   15
# 5    208       19    53  232
# 6    154       16    51  232
# 7    202       14    31   17
# 8    202       22    61   22
# 9    290       53    22   22
# 10   210       51    53   53
# 11   260       31    91   91
# 12   310       61   168  168
# 13   214       22    15   15
# 14   145       53   232  232
# 15   183       91   232  232
# 16   342      168    17   17
# 17   165       15    22   22
# 18   293      232   116   16
# 19   293      232    16   64
# 20   610       17    52   60
# 21   482       22   875   14
# 22   542      116   875   27
# 23   231       16  1680   19
# 24   194       52    20   16
# 25   289      875    13   14
# 26   289      875    45   22
# 27   240     1680    35   53
# 28   128       20    19   51
# 29   188       13    59   31
# ..   ...      ...   ...  ...
# ...

# %%
import numpy as ip
import seaborn as sea
import matplotlib.pyplot as mat
from scipy import stats
import pandas as data

cek = data.read_csv("calvins.csv")
mode = stats.mode(cek)
print(mode)
# Out:
# ModeResult(mode=array([[198,  25,  25,  20]], dtype=int64), count=array([[10, 22, 22, 28]]))

# %%
import numpy as ip
import seaborn as sea
import matplotlib.pyplot as mat
from scipy import stats
import pandas as dt

for i in range(3):
    hasil=dt.read_csv("calvins.csv",usecols=[i])
    sea.distplot(hasil);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
